# %% [markdown]
# # MAP-Elites Track Generations

# %%
import sys
import os

# Get the current working directory
cwd = os.getcwd()
print(f"Current Working Directory: {cwd}")

# Define the path to the 'mapelite' folder
# We assume the notebook is running from the root 'Quality-Diversity-...' folder
mapelite_path = os.path.join(cwd, 'mapelite')

# Add it to the system path so Python can find config.py, utils.py, etc.
if mapelite_path not in sys.path:
    sys.path.append(mapelite_path)
    print(f"Added '{mapelite_path}' to sys.path")
# Out:
# Current Working Directory: D:\dev\Quality-Diversity-for-Racing-Track-Design

# %%
import numpy as np
import requests
import random
import matplotlib.pyplot as plt
import joblib    
import glob
import os
import pickle

from ribs.archives import SlidingBoundariesArchive
from ribs.schedulers import Scheduler
from ribs.visualize import sliding_boundaries_archive_heatmap
from dask.distributed import Client, LocalCluster, as_completed

# --- Import Modular Code ---
from config import (
    ITERATIONS, BATCH_SIZE, INVALID_SCORE, CHECKPOINT_EVERY, 
    CHECKPOINT_DIR, HEATMAP_DIR, SOLUTION_DIM, ARCHIVE_BINS, 
    REMAPPING_EVERY, BUFFER_SIZE, INIT_POPULATION
)
from utils import array_to_solution, get_initial_archive_ranges
from evaluator import evaluate_solution_MAPElite
from emitter import CustomEmitter

# %%
# --- Initialize directories ---
# Create directories if they don't exist
os.makedirs(CHECKPOINT_DIR, exist_ok=True)
os.makedirs(HEATMAP_DIR, exist_ok=True)

# %%
# --- DASK SETUP ---
print("Setting up Dask LocalCluster...")
cluster = LocalCluster(processes=True, n_workers=BATCH_SIZE, threads_per_worker=1)
client = Client(cluster)
print(f"Dask Dashboard link: {client.dashboard_link}")
# Out:
# Setting up Dask LocalCluster...
# D:\dev\Quality-Diversity-for-Racing-Track-Design\venv\Lib\site-packages\distributed\node.py:188: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 62655 instead
#   warnings.warn(
# C:\Users\milob\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:144: UserWarning: Creating scratch directories is taking a surprisingly long time. (3.05s) This is often due to running workers on a network file system. Consider specifying a local-directory to point workers to write scratch data to a local disk.
#   next(self.gen)
# Dask Dashboard link: http://127.0.0.1:62655/status

# %%
ranges = get_initial_archive_ranges()

# --- Initialize Archive and Scheduler ---
archive = SlidingBoundariesArchive(
    solution_dim=SOLUTION_DIM,
    dims=[ARCHIVE_BINS, ARCHIVE_BINS], # UMAP dimensions
    ranges=ranges,         # UMAP descriptor ranges
    remap_frequency=REMAPPING_EVERY,
    buffer_capacity=BUFFER_SIZE
)

emitter = CustomEmitter(
    archive,
    solution_dim=SOLUTION_DIM,
    batch_size=BATCH_SIZE,
    # Last element (ID) can be arbitrarily large (ID=iteration + fractional_part)
    bounds=[(0, 600)] * (SOLUTION_DIM - 1) + [(0, float("inf"))]
)

scheduler = Scheduler(archive, [emitter])

# --------------------------------------------------------------
# Resume from latest pickle checkpoint if one exists
# --------------------------------------------------------------
checkpoints = sorted(glob.glob(f"{CHECKPOINT_DIR}checkpoint_*.pkl"))
start_iter = 0
global_best_score = INVALID_SCORE
global_best_id = None

if checkpoints:
    latest_ckpt = checkpoints[-1]
    with open(latest_ckpt, "rb") as f:
        state = pickle.load(f)
    scheduler           = state["scheduler"]
    # Get the latest archive instance from the scheduler
    archive             = scheduler.archive
    start_iter          = state["iteration"]
    global_best_score   = state["global_best_score"]
    global_best_id      = state["global_best_id"]
    print(f"[Resume] Loaded {latest_ckpt}, resuming from iteration {start_iter+1}")
else:
    print("[Resume] No checkpoint found — starting fresh.")


def run_map_elites(total_iters, start_iter=0):
    # declare that we mean to update these module-level variables
    global global_best_score, global_best_id
    
    for i in range(start_iter, total_iters):
        print(f"\n=== Starting iteration {i+1} ===")
        
        # 1. Ask the emitter for a batch of solutions
        sols = scheduler.ask()
        sol_dicts = [array_to_solution(s) for s in sols]
        
        # 2. Evaluate solutions in parallel using Dask
        futs = [client.submit(evaluate_solution_MAPElite, sol) for sol in sol_dicts]
        # Block until all evaluations are complete
        gathered = [f.result() for f in as_completed(futs)]

        obj_list, clean_solutions = [], []
        
        for sol_id, ok, msg, score, desc in gathered:
            
            if not ok:
                print(f"Warning: clamping bad score for ID={sol_id} ({msg})")
                score = INVALID_SCORE
            else:
                # to calculate 'score'
                print(f"Solution ID={sol_id} evaluated with score={score:.2f}")
                if score > global_best_score:
                    global_best_score = score
                    global_best_id = sol_id
            
            clean_solutions.append((score, desc))
            obj_list.append(score)

        # 3. Tell the scheduler the results
        obj_batch, meas_batch = zip(*clean_solutions)
        scheduler.tell(list(obj_batch), list(meas_batch))

        # 4. Log statistics
        batch_best = max(obj_list) if obj_list else INVALID_SCORE
        print(f"Iteration {i+1} ended. Best in batch = {batch_best:.2f}")
        print(f"Global best so far: {global_best_score:.2f} (ID={global_best_id})")

        data_archive = archive.data()
        if data_archive:
            arch_obj = data_archive["objective"]
            valid = arch_obj != INVALID_SCORE
            mean_val = np.mean(arch_obj[valid]) if np.any(valid) else 0.0
            best_val = np.max(arch_obj[valid]) if np.any(valid) else 0.0
            cov = archive.stats.coverage
            print(f"Archive size={len(archive)}, cov={cov:.3f}, mean={mean_val:.2f}, best={best_val:.2f}")
        else:
            print("Archive still empty")

        # 5. Checkpoint
        if (i + 1) % CHECKPOINT_EVERY == 0:
            ckpt_name = f"{CHECKPOINT_DIR}checkpoint_{i+1:04d}.pkl"
            with open(ckpt_name, "wb") as f:
                pickle.dump({
                    "scheduler": scheduler,
                    "iteration": i+1,
                    "global_best_score": global_best_score,
                    "global_best_id": global_best_id
                }, f)
            print(f"[Checkpoint] Saved {ckpt_name}")

        # 6. Plot Heatmap
        if (i + 1) % 10 == 0:
            arch_obj = np.array(archive.data()["objective"])
            valid = arch_obj != INVALID_SCORE
            
            if np.any(valid):
                p_low, p_high = np.percentile(arch_obj[valid], [20, 80])
            else:
                p_low = p_high = 0.0

            fig = plt.figure(figsize=(8, 6))
            sliding_boundaries_archive_heatmap(
                archive,
                boundary_lw=0.5,
                vmin=p_low,
                vmax=p_high,
            )
            plt.title(f"Archive Heat-map – Iteration {i+1}")
            plt.xlabel("UMAP-1")
            plt.ylabel("UMAP-2")
            plt.tight_layout()
            plt.savefig(f"{HEATMAP_DIR}archive_heatmap_iter_{i+1}.png")
            plt.close(fig)
# Out:
# [Archive Init] Auto-detected ranges: X=(np.float32(0.5492356), np.float32(20.738216)), Y=(np.float32(-1.5278269), np.float32(13.583673))
# [Resume] Loaded data/checkpoints\checkpoint_0950.pkl, resuming from iteration 951

# %%
# Run the main loop
run_map_elites(ITERATIONS, start_iter)
# Out:
# === Starting iteration 951 ===
# Emitter.ask() called for iteration 951
# Mutating solutions for iteration 951
# Solution ID=950.3152829585116 evaluated with score=16.50
# Solution ID=950.4194380856816 evaluated with score=15.50
# Solution ID=950.0120193390849 evaluated with score=9.75
# Solution ID=950.811969630072 evaluated with score=8.50
# Solution ID=950.5769581529753 evaluated with score=6.00
# Solution ID=950.3218571663001 evaluated with score=32.25
# Solution ID=950.7375224066602 evaluated with score=24.50
# Solution ID=950.027161208198 evaluated with score=13.25
# Solution ID=950.8350801357448 evaluated with score=17.50
# Solution ID=950.5185309877501 evaluated with score=9.75
# Iteration 951 ended. Best in batch = 32.25
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=480, cov=0.533, mean=21.02, best=45.25
#
# === Starting iteration 952 ===
# Emitter.ask() called for iteration 952
# Crossover solutions for iteration 952
# Solution ID=951.317495382079 evaluated with score=4.00
# Solution ID=951.317495382079 evaluated with score=4.00
# Solution ID=951.8897501383708 evaluated with score=10.00
# Solution ID=951.8897501383708 evaluated with score=10.00
# Solution ID=951.0553689337407 evaluated with score=11.25
# Solution ID=951.0553689337407 evaluated with score=11.25
# Solution ID=951.9319754072491 evaluated with score=13.00
# Solution ID=951.9319754072491 evaluated with score=13.00
# Solution ID=951.7039666487287 evaluated with score=19.75
# Solution ID=951.7039666487287 evaluated with score=19.75
# Iteration 952 ended. Best in batch = 19.75
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=482, cov=0.536, mean=20.99, best=45.25
#
# === Starting iteration 953 ===
# Emitter.ask() called for iteration 953
# Mutating solutions for iteration 953
# Solution ID=952.3968042261095 evaluated with score=13.75
# Solution ID=952.4457164323665 evaluated with score=8.50
# Solution ID=952.2672458380483 evaluated with score=24.25
# Solution ID=952.8703597410649 evaluated with score=11.50
# Solution ID=952.4362150583966 evaluated with score=7.75
# Solution ID=952.7264682789926 evaluated with score=11.25
# Solution ID=952.73695333856 evaluated with score=6.50
# Solution ID=952.0383426839276 evaluated with score=13.75
# Solution ID=952.0309741998784 evaluated with score=13.75
# Solution ID=952.4551159242012 evaluated with score=16.75
# Iteration 953 ended. Best in batch = 24.25
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=483, cov=0.537, mean=20.96, best=45.25
#
# === Starting iteration 954 ===
# Emitter.ask() called for iteration 954
# Crossover solutions for iteration 954
# Solution ID=953.7193448091864 evaluated with score=10.50
# Solution ID=953.7193448091864 evaluated with score=10.50
# Solution ID=953.2020359016221 evaluated with score=11.50
# Solution ID=953.2020359016221 evaluated with score=11.50
# Solution ID=953.9465288372375 evaluated with score=17.50
# Solution ID=953.9465288372375 evaluated with score=17.50
# Solution ID=953.6827703218185 evaluated with score=13.50
# Solution ID=953.6827703218185 evaluated with score=13.50
# Solution ID=953.2581791545529 evaluated with score=6.75
# Solution ID=953.2581791545529 evaluated with score=6.75
# Iteration 954 ended. Best in batch = 17.50
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=483, cov=0.537, mean=20.96, best=45.25
#
# === Starting iteration 955 ===
# Emitter.ask() called for iteration 955
# Crossover solutions for iteration 955
# Solution ID=954.9916773421996 evaluated with score=8.75
# Solution ID=954.9916773421996 evaluated with score=8.75
# Solution ID=954.2342856626553 evaluated with score=7.25
# Solution ID=954.2342856626553 evaluated with score=7.25
# Solution ID=954.6837321855425 evaluated with score=14.50
# Solution ID=954.6837321855425 evaluated with score=14.50
# Solution ID=954.2719439339356 evaluated with score=10.00
# Solution ID=954.2719439339356 evaluated with score=10.00
# Solution ID=954.5944290022962 evaluated with score=16.50
# Solution ID=954.5944290022962 evaluated with score=16.50
# Iteration 955 ended. Best in batch = 16.50
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=484, cov=0.538, mean=20.95, best=45.25
#
# === Starting iteration 956 ===
# Emitter.ask() called for iteration 956
# Crossover solutions for iteration 956
# Solution ID=955.8365885918515 evaluated with score=8.00
# Solution ID=955.8365885918515 evaluated with score=8.00
# Solution ID=955.86048917676 evaluated with score=22.75
# Solution ID=955.86048917676 evaluated with score=22.75
# Solution ID=955.4366205693241 evaluated with score=14.25
# Solution ID=955.4366205693241 evaluated with score=14.25
# Solution ID=955.6051061788504 evaluated with score=8.00
# Solution ID=955.6051061788504 evaluated with score=8.00
# Solution ID=955.6463985550361 evaluated with score=5.25
# Solution ID=955.6463985550361 evaluated with score=5.25
# Iteration 956 ended. Best in batch = 22.75
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=484, cov=0.538, mean=20.95, best=45.25
#
# === Starting iteration 957 ===
# Emitter.ask() called for iteration 957
# Mutating solutions for iteration 957
# Solution ID=956.0838826677902 evaluated with score=18.00
# Solution ID=956.1645189421397 evaluated with score=19.75
# Solution ID=956.6458152020127 evaluated with score=17.00
# Solution ID=956.6368825103551 evaluated with score=21.25
# Solution ID=956.1652805158287 evaluated with score=6.50
# Solution ID=956.298602311525 evaluated with score=3.75
# Solution ID=956.4362150583966 evaluated with score=9.25
# Solution ID=956.2416491195712 evaluated with score=22.00
# Solution ID=956.6609299250802 evaluated with score=18.50
# Solution ID=956.7645591527491 evaluated with score=14.75
# Iteration 957 ended. Best in batch = 22.00
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=488, cov=0.542, mean=20.93, best=45.25
#
# === Starting iteration 958 ===
# Emitter.ask() called for iteration 958
# Crossover solutions for iteration 958
# Solution ID=957.7517569577069 evaluated with score=10.25
# Solution ID=957.7517569577069 evaluated with score=10.25
# Solution ID=957.0803114034123 evaluated with score=2.75
# Solution ID=957.0803114034123 evaluated with score=2.75
# Solution ID=957.7159430130497 evaluated with score=13.75
# Solution ID=957.7159430130497 evaluated with score=13.75
# Solution ID=957.1782158336692 evaluated with score=8.25
# Solution ID=957.1782158336692 evaluated with score=8.25
# Solution ID=957.386533783714 evaluated with score=7.50
# Solution ID=957.386533783714 evaluated with score=7.50
# Iteration 958 ended. Best in batch = 13.75
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=489, cov=0.543, mean=20.91, best=45.25
#
# === Starting iteration 959 ===
# Emitter.ask() called for iteration 959
# Mutating solutions for iteration 959
# Warning: clamping bad score for ID=958.0648780525161 (500 Server Error: Internal Server Error for url: http://localhost:4242/evaluate)
# Solution ID=958.8699902975347 evaluated with score=6.75
# Solution ID=958.6202802026811 evaluated with score=17.00
# Solution ID=958.0648780525161 evaluated with score=4.75
# Solution ID=958.4194380856816 evaluated with score=19.50
# Solution ID=958.4698632913096 evaluated with score=7.75
# Solution ID=958.7137990316705 evaluated with score=25.50
# Solution ID=958.6996011533873 evaluated with score=10.50
# Solution ID=958.7754829769993 evaluated with score=38.75
# Solution ID=958.027161208198 evaluated with score=13.75
# Iteration 959 ended. Best in batch = 38.75
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=492, cov=0.547, mean=20.91, best=45.25
#
# === Starting iteration 960 ===
# Emitter.ask() called for iteration 960
# Crossover solutions for iteration 960
# Solution ID=959.6560925448072 evaluated with score=11.50
# Solution ID=959.6560925448072 evaluated with score=11.50
# Solution ID=959.6453729418733 evaluated with score=8.75
# Solution ID=959.6453729418733 evaluated with score=8.75
# Solution ID=959.672802504972 evaluated with score=9.25
# Solution ID=959.672802504972 evaluated with score=9.25
# Solution ID=959.2200831668347 evaluated with score=3.75
# Solution ID=959.2200831668347 evaluated with score=3.75
# Solution ID=959.483534633808 evaluated with score=2.50
# Solution ID=959.483534633808 evaluated with score=2.50
# Iteration 960 ended. Best in batch = 11.50
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=483, cov=0.537, mean=20.92, best=45.25
#
# === Starting iteration 961 ===
# Emitter.ask() called for iteration 961
# Crossover solutions for iteration 961
# Solution ID=960.2843446314265 evaluated with score=12.50
# Solution ID=960.2843446314265 evaluated with score=12.50
# Solution ID=960.0589401706916 evaluated with score=10.25
# Solution ID=960.0589401706916 evaluated with score=10.25
# Solution ID=960.0328876114675 evaluated with score=9.25
# Solution ID=960.0328876114675 evaluated with score=9.25
# Solution ID=960.5998580031206 evaluated with score=5.25
# Solution ID=960.5998580031206 evaluated with score=5.25
# Solution ID=960.4515898308755 evaluated with score=26.75
# Solution ID=960.4515898308755 evaluated with score=26.75
# Iteration 961 ended. Best in batch = 26.75
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=485, cov=0.539, mean=20.87, best=45.25
#
# === Starting iteration 962 ===
# Emitter.ask() called for iteration 962
# Mutating solutions for iteration 962
# Solution ID=961.2669799642398 evaluated with score=12.25
# Solution ID=961.1115794415574 evaluated with score=7.00
# Solution ID=961.864299767789 evaluated with score=7.75
# Solution ID=961.7786582287536 evaluated with score=16.75
# Solution ID=961.5788887375257 evaluated with score=14.75
# Solution ID=961.5907949980208 evaluated with score=23.25
# Solution ID=961.5467141494833 evaluated with score=8.50
# Solution ID=961.8944979972639 evaluated with score=7.25
# Solution ID=961.5769581529753 evaluated with score=9.25
# Solution ID=961.677796661102 evaluated with score=19.75
# Iteration 962 ended. Best in batch = 23.25
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=486, cov=0.540, mean=20.88, best=45.25
#
# === Starting iteration 963 ===
# Emitter.ask() called for iteration 963
# Crossover solutions for iteration 963
# Solution ID=962.2995183689267 evaluated with score=4.50
# Solution ID=962.2995183689267 evaluated with score=4.50
# Solution ID=962.6851582551972 evaluated with score=22.50
# Solution ID=962.6851582551972 evaluated with score=22.50
# Solution ID=962.278888578981 evaluated with score=22.25
# Solution ID=962.278888578981 evaluated with score=22.25
# Solution ID=962.3248271186899 evaluated with score=19.00
# Solution ID=962.3248271186899 evaluated with score=19.00
# Solution ID=962.6270031173551 evaluated with score=5.75
# Solution ID=962.6270031173551 evaluated with score=5.75
# Iteration 963 ended. Best in batch = 22.50
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=488, cov=0.542, mean=20.85, best=45.25
#
# === Starting iteration 964 ===
# Emitter.ask() called for iteration 964
# Crossover solutions for iteration 964
# Solution ID=963.3520834975036 evaluated with score=10.25
# Solution ID=963.3520834975036 evaluated with score=10.25
# Solution ID=963.2317316595806 evaluated with score=5.50
# Solution ID=963.2317316595806 evaluated with score=5.50
# Solution ID=963.9247391211738 evaluated with score=6.50
# Solution ID=963.9247391211738 evaluated with score=6.50
# Solution ID=963.1059631919195 evaluated with score=11.50
# Solution ID=963.1059631919195 evaluated with score=11.50
# Solution ID=963.3189351671058 evaluated with score=7.75
# Solution ID=963.3189351671058 evaluated with score=7.75
# Iteration 964 ended. Best in batch = 11.50
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=488, cov=0.542, mean=20.85, best=45.25
#
# === Starting iteration 965 ===
# Emitter.ask() called for iteration 965
# Crossover solutions for iteration 965
# Solution ID=964.6102353745061 evaluated with score=16.50
# Solution ID=964.6102353745061 evaluated with score=16.50
# Solution ID=964.9129906267577 evaluated with score=24.50
# Solution ID=964.9129906267577 evaluated with score=24.50
# Solution ID=964.3132801500758 evaluated with score=19.75
# Solution ID=964.3132801500758 evaluated with score=19.75
# Solution ID=964.2197638554059 evaluated with score=11.00
# Solution ID=964.2197638554059 evaluated with score=11.00
# Solution ID=964.3450023568724 evaluated with score=15.50
# Solution ID=964.3450023568724 evaluated with score=15.50
# Iteration 965 ended. Best in batch = 24.50
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=489, cov=0.543, mean=20.87, best=45.25
#
# === Starting iteration 966 ===
# Emitter.ask() called for iteration 966
# Mutating solutions for iteration 966
# Solution ID=965.6032288532814 evaluated with score=12.25
# Solution ID=965.1762200619823 evaluated with score=9.75
# Solution ID=965.9165366428567 evaluated with score=8.50
# Solution ID=965.6246051414257 evaluated with score=16.75
# Solution ID=965.2395362624753 evaluated with score=7.00
# Solution ID=965.9289855269299 evaluated with score=13.50
# Solution ID=965.7831932540863 evaluated with score=22.75
# Solution ID=965.0383426839276 evaluated with score=13.25
# Solution ID=965.8938235622684 evaluated with score=12.50
# Solution ID=965.501996161528 evaluated with score=17.00
# Iteration 966 ended. Best in batch = 22.75
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=490, cov=0.544, mean=20.90, best=45.25
#
# === Starting iteration 967 ===
# Emitter.ask() called for iteration 967
# Mutating solutions for iteration 967
# Solution ID=966.4062127648671 evaluated with score=11.00
# Solution ID=966.1779338159893 evaluated with score=16.50
# Solution ID=966.5998580031206 evaluated with score=3.50
# Solution ID=966.7626528331641 evaluated with score=11.25
# Solution ID=966.1779338159893 evaluated with score=15.50
# Solution ID=966.2357674399441 evaluated with score=9.25
# Solution ID=966.6531218062194 evaluated with score=10.50
# Solution ID=966.5467141494833 evaluated with score=18.00
# Solution ID=966.3218571663001 evaluated with score=14.50
# Solution ID=966.2416491195712 evaluated with score=25.50
# Iteration 967 ended. Best in batch = 25.50
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=490, cov=0.544, mean=20.91, best=45.25
#
# === Starting iteration 968 ===
# Emitter.ask() called for iteration 968
# Mutating solutions for iteration 968
# Solution ID=967.9739228287353 evaluated with score=9.00
# Solution ID=967.3152829585116 evaluated with score=20.50
# Solution ID=967.9278652207555 evaluated with score=11.25
# Solution ID=967.3241579339817 evaluated with score=22.25
# Solution ID=967.5070775266809 evaluated with score=5.25
# Solution ID=967.6202802026811 evaluated with score=16.50
# Solution ID=967.4012412172975 evaluated with score=15.25
# Solution ID=967.9592909768377 evaluated with score=11.75
# Solution ID=967.2697170134757 evaluated with score=12.75
# Solution ID=967.5244776734478 evaluated with score=13.75
# Iteration 968 ended. Best in batch = 22.25
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=492, cov=0.547, mean=20.87, best=45.25
#
# === Starting iteration 969 ===
# Emitter.ask() called for iteration 969
# Mutating solutions for iteration 969
# Solution ID=968.8699752347145 evaluated with score=11.75
# Solution ID=968.4672513383457 evaluated with score=12.50
# Solution ID=968.2136996585984 evaluated with score=9.75
# Solution ID=968.3152829585116 evaluated with score=23.50
# Solution ID=968.2395362624753 evaluated with score=3.75
# Solution ID=968.9914154874695 evaluated with score=37.50
# Solution ID=968.963205078783 evaluated with score=14.00
# Solution ID=968.7375224066602 evaluated with score=15.25
# Solution ID=968.9626027323893 evaluated with score=15.00
# Solution ID=968.9265156123624 evaluated with score=6.25
# Iteration 969 ended. Best in batch = 37.50
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=492, cov=0.547, mean=20.92, best=45.25
#
# === Starting iteration 970 ===
# Emitter.ask() called for iteration 970
# Crossover solutions for iteration 970
# Solution ID=969.6295094025027 evaluated with score=11.50
# Solution ID=969.6295094025027 evaluated with score=11.50
# Solution ID=969.7905892089545 evaluated with score=12.00
# Solution ID=969.7905892089545 evaluated with score=12.00
# Solution ID=969.0412047628517 evaluated with score=8.75
# Solution ID=969.0412047628517 evaluated with score=8.75
# Solution ID=969.9147833546799 evaluated with score=40.50
# Solution ID=969.9147833546799 evaluated with score=40.50
# Solution ID=969.1225728362159 evaluated with score=16.50
# Solution ID=969.1225728362159 evaluated with score=16.50
# Iteration 970 ended. Best in batch = 40.50
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=483, cov=0.537, mean=21.12, best=45.25
#
# === Starting iteration 971 ===
# Emitter.ask() called for iteration 971
# Mutating solutions for iteration 971
# Warning: clamping bad score for ID=970.760189197674 (500 Server Error: Internal Server Error for url: http://localhost:4242/evaluate)
# Warning: clamping bad score for ID=970.1232102372237 (500 Server Error: Internal Server Error for url: http://localhost:4242/evaluate)
# Solution ID=970.677796661102 evaluated with score=10.00
# Solution ID=970.9139714793729 evaluated with score=16.00
# Solution ID=970.6246051414257 evaluated with score=8.00
# Solution ID=970.760189197674 evaluated with score=17.50
# Solution ID=970.3132801500758 evaluated with score=7.25
# Solution ID=970.7831932540863 evaluated with score=17.25
# Solution ID=970.7114839022814 evaluated with score=10.25
# Solution ID=970.3659661732611 evaluated with score=25.75
# Iteration 971 ended. Best in batch = 25.75
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=484, cov=0.538, mean=21.13, best=45.25
#
# === Starting iteration 972 ===
# Emitter.ask() called for iteration 972
# Mutating solutions for iteration 972
# Solution ID=971.4195898717222 evaluated with score=19.00
# Solution ID=971.5574886625704 evaluated with score=7.25
# Solution ID=971.4457164323665 evaluated with score=12.50
# Solution ID=971.9974501286708 evaluated with score=9.00
# Solution ID=971.4963776044709 evaluated with score=7.25
# Solution ID=971.7905892089545 evaluated with score=12.75
# Solution ID=971.0383426839276 evaluated with score=15.00
# Solution ID=971.014968255531 evaluated with score=14.75
# Solution ID=971.6403336095057 evaluated with score=5.50
# Solution ID=971.6743114204602 evaluated with score=27.50
# Iteration 972 ended. Best in batch = 27.50
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=484, cov=0.538, mean=21.18, best=45.25
#
# === Starting iteration 973 ===
# Emitter.ask() called for iteration 973
# Mutating solutions for iteration 973
# Solution ID=972.5844160861202 evaluated with score=11.00
# Solution ID=972.6458152020127 evaluated with score=12.50
# Solution ID=972.4619417096094 evaluated with score=7.75
# Solution ID=972.199945475389 evaluated with score=14.00
# Solution ID=972.9147833546799 evaluated with score=11.75
# Solution ID=972.8164594847839 evaluated with score=16.00
# Solution ID=972.7375224066602 evaluated with score=14.75
# Solution ID=972.2604832946239 evaluated with score=12.75
# Solution ID=972.8755449747462 evaluated with score=9.50
# Solution ID=972.0107738463906 evaluated with score=7.75
# Iteration 973 ended. Best in batch = 16.00
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=486, cov=0.540, mean=21.15, best=45.25
#
# === Starting iteration 974 ===
# Emitter.ask() called for iteration 974
# Mutating solutions for iteration 974
# Warning: clamping bad score for ID=973.7780297649165 (500 Server Error: Internal Server Error for url: http://localhost:4242/evaluate)
# Solution ID=973.5336762893314 evaluated with score=15.75
# Solution ID=973.0206311445168 evaluated with score=7.25
# Solution ID=973.7420201843144 evaluated with score=27.00
# Solution ID=973.4194380856816 evaluated with score=10.50
# Solution ID=973.4362150583966 evaluated with score=10.00
# Solution ID=973.0128322681295 evaluated with score=31.00
# Solution ID=973.4619417096094 evaluated with score=22.75
# Solution ID=973.6531218062194 evaluated with score=5.25
# Solution ID=973.7580722246967 evaluated with score=4.75
# Iteration 974 ended. Best in batch = 31.00
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=486, cov=0.540, mean=21.19, best=45.25
#
# === Starting iteration 975 ===
# Emitter.ask() called for iteration 975
# Crossover solutions for iteration 975
# Solution ID=974.059852503737 evaluated with score=10.75
# Solution ID=974.059852503737 evaluated with score=10.75
# Solution ID=974.58907452719 evaluated with score=9.00
# Solution ID=974.58907452719 evaluated with score=9.00
# Solution ID=974.8668990397501 evaluated with score=11.25
# Solution ID=974.8668990397501 evaluated with score=11.25
# Solution ID=974.8637121479053 evaluated with score=31.75
# Solution ID=974.8637121479053 evaluated with score=31.75
# Solution ID=974.5090879470519 evaluated with score=8.75
# Solution ID=974.5090879470519 evaluated with score=8.75
# Iteration 975 ended. Best in batch = 31.75
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=486, cov=0.540, mean=21.22, best=45.25
#
# === Starting iteration 976 ===
# Emitter.ask() called for iteration 976
# Crossover solutions for iteration 976
# Solution ID=975.858680051834 evaluated with score=12.00
# Solution ID=975.858680051834 evaluated with score=12.00
# Solution ID=975.7461040959377 evaluated with score=7.25
# Solution ID=975.7461040959377 evaluated with score=7.25
# Solution ID=975.1265633086265 evaluated with score=12.00
# Solution ID=975.1265633086265 evaluated with score=12.00
# Solution ID=975.6145399617981 evaluated with score=17.50
# Solution ID=975.6145399617981 evaluated with score=17.50
# Solution ID=975.9199625468119 evaluated with score=9.75
# Solution ID=975.9199625468119 evaluated with score=9.75
# Iteration 976 ended. Best in batch = 17.50
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=487, cov=0.541, mean=21.20, best=45.25
#
# === Starting iteration 977 ===
# Emitter.ask() called for iteration 977
# Mutating solutions for iteration 977
# Solution ID=976.3152829585116 evaluated with score=7.75
# Solution ID=976.9289855269299 evaluated with score=9.00
# Solution ID=976.998229760901 evaluated with score=19.50
# Solution ID=976.2061841085418 evaluated with score=10.75
# Solution ID=976.6246051414257 evaluated with score=22.00
# Solution ID=976.0580449675879 evaluated with score=14.75
# Solution ID=976.324543652257 evaluated with score=10.50
# Solution ID=976.963205078783 evaluated with score=10.00
# Solution ID=976.5922324380417 evaluated with score=14.00
# Solution ID=976.2798837006605 evaluated with score=5.00
# Iteration 977 ended. Best in batch = 22.00
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=488, cov=0.542, mean=21.23, best=45.25
#
# === Starting iteration 978 ===
# Emitter.ask() called for iteration 978
# Mutating solutions for iteration 978
# Solution ID=977.8699902975347 evaluated with score=11.50
# Solution ID=977.4423928862087 evaluated with score=10.75
# Solution ID=977.6607215316901 evaluated with score=7.50
# Solution ID=977.7477363882819 evaluated with score=32.25
# Solution ID=977.760189197674 evaluated with score=5.75
# Solution ID=977.1918474638348 evaluated with score=10.75
# Solution ID=977.7855629613588 evaluated with score=9.50
# Solution ID=977.0383426839276 evaluated with score=15.00
# Solution ID=977.462948629751 evaluated with score=9.50
# Solution ID=977.7645591527491 evaluated with score=11.50
# Iteration 978 ended. Best in batch = 32.25
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=488, cov=0.542, mean=21.26, best=45.25
#
# === Starting iteration 979 ===
# Emitter.ask() called for iteration 979
# Mutating solutions for iteration 979
# Solution ID=978.7264682789926 evaluated with score=10.00
# Solution ID=978.9139714793729 evaluated with score=13.25
# Solution ID=978.6295094025027 evaluated with score=14.00
# Solution ID=978.7107715224273 evaluated with score=10.00
# Solution ID=978.3250037625025 evaluated with score=7.25
# Solution ID=978.6531218062194 evaluated with score=12.75
# Solution ID=978.2239834678725 evaluated with score=10.50
# Solution ID=978.2396661230738 evaluated with score=13.50
# Solution ID=978.4625921791067 evaluated with score=10.75
# Solution ID=978.4551159242012 evaluated with score=8.50
# Iteration 979 ended. Best in batch = 14.00
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=489, cov=0.543, mean=21.24, best=45.25
#
# === Starting iteration 980 ===
# Emitter.ask() called for iteration 980
# Crossover solutions for iteration 980
# Solution ID=979.338620120167 evaluated with score=22.00
# Solution ID=979.338620120167 evaluated with score=22.00
# Solution ID=979.6902454105367 evaluated with score=12.75
# Solution ID=979.6902454105367 evaluated with score=12.75
# Solution ID=979.0701045257925 evaluated with score=17.75
# Solution ID=979.0701045257925 evaluated with score=17.75
# Solution ID=979.9700648232283 evaluated with score=24.75
# Solution ID=979.9700648232283 evaluated with score=24.75
# Solution ID=979.278019991933 evaluated with score=11.75
# Solution ID=979.278019991933 evaluated with score=11.75
# Iteration 980 ended. Best in batch = 24.75
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=489, cov=0.543, mean=20.98, best=45.25
#
# === Starting iteration 981 ===
# Emitter.ask() called for iteration 981
# Crossover solutions for iteration 981
# Solution ID=980.8948876185656 evaluated with score=5.50
# Solution ID=980.8948876185656 evaluated with score=5.50
# Solution ID=980.6911504711936 evaluated with score=22.75
# Solution ID=980.6911504711936 evaluated with score=22.75
# Solution ID=980.0362965408407 evaluated with score=14.25
# Solution ID=980.0362965408407 evaluated with score=14.25
# Solution ID=980.6841277267038 evaluated with score=10.00
# Solution ID=980.6841277267038 evaluated with score=10.00
# Solution ID=980.6058638188474 evaluated with score=6.25
# Solution ID=980.6058638188474 evaluated with score=6.25
# Iteration 981 ended. Best in batch = 22.75
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=491, cov=0.546, mean=20.96, best=45.25
#
# === Starting iteration 982 ===
# Emitter.ask() called for iteration 982
# Crossover solutions for iteration 982
# Warning: clamping bad score for ID=981.7770341644004 (500 Server Error: Internal Server Error for url: http://localhost:4242/evaluate)
# Warning: clamping bad score for ID=981.7770341644004 (500 Server Error: Internal Server Error for url: http://localhost:4242/evaluate)
# Solution ID=981.352030748549 evaluated with score=17.50
# Solution ID=981.352030748549 evaluated with score=17.50
# Solution ID=981.5505944630105 evaluated with score=18.50
# Solution ID=981.5505944630105 evaluated with score=18.50
# Solution ID=981.0305344821609 evaluated with score=14.50
# Solution ID=981.0305344821609 evaluated with score=14.50
# Solution ID=981.6029883346513 evaluated with score=7.75
# Solution ID=981.6029883346513 evaluated with score=7.75
# Iteration 982 ended. Best in batch = 18.50
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=491, cov=0.546, mean=20.98, best=45.25
#
# === Starting iteration 983 ===
# Emitter.ask() called for iteration 983
# Crossover solutions for iteration 983
# Solution ID=982.9055125881175 evaluated with score=8.75
# Solution ID=982.9055125881175 evaluated with score=8.75
# Solution ID=982.678508956721 evaluated with score=17.75
# Solution ID=982.678508956721 evaluated with score=17.75
# Solution ID=982.1551870407349 evaluated with score=10.25
# Solution ID=982.1551870407349 evaluated with score=10.25
# Solution ID=982.506818342022 evaluated with score=15.50
# Solution ID=982.506818342022 evaluated with score=15.50
# Solution ID=982.1387406497554 evaluated with score=15.50
# Solution ID=982.1387406497554 evaluated with score=15.50
# Iteration 983 ended. Best in batch = 17.75
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=492, cov=0.547, mean=20.97, best=45.25
#
# === Starting iteration 984 ===
# Emitter.ask() called for iteration 984
# Crossover solutions for iteration 984
# Solution ID=983.3595807641941 evaluated with score=27.00
# Solution ID=983.3595807641941 evaluated with score=27.00
# Solution ID=983.5281116156148 evaluated with score=5.25
# Solution ID=983.5281116156148 evaluated with score=5.25
# Solution ID=983.8915851056655 evaluated with score=22.25
# Solution ID=983.8915851056655 evaluated with score=22.25
# Solution ID=983.7298545851697 evaluated with score=12.25
# Solution ID=983.7298545851697 evaluated with score=12.25
# Solution ID=983.3480629280785 evaluated with score=23.75
# Solution ID=983.3480629280785 evaluated with score=23.75
# Iteration 984 ended. Best in batch = 27.00
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=494, cov=0.549, mean=20.99, best=45.25
#
# === Starting iteration 985 ===
# Emitter.ask() called for iteration 985
# Crossover solutions for iteration 985
# Solution ID=984.1390744813231 evaluated with score=15.50
# Solution ID=984.1390744813231 evaluated with score=15.50
# Solution ID=984.5213574751348 evaluated with score=11.00
# Solution ID=984.5213574751348 evaluated with score=11.00
# Solution ID=984.7242162772959 evaluated with score=6.75
# Solution ID=984.7242162772959 evaluated with score=6.75
# Solution ID=984.2433405549026 evaluated with score=5.00
# Solution ID=984.2433405549026 evaluated with score=5.00
# Solution ID=984.4210490060537 evaluated with score=10.00
# Solution ID=984.4210490060537 evaluated with score=10.00
# Iteration 985 ended. Best in batch = 15.50
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=496, cov=0.551, mean=20.95, best=45.25
#
# === Starting iteration 986 ===
# Emitter.ask() called for iteration 986
# Crossover solutions for iteration 986
# Solution ID=985.8307892499676 evaluated with score=15.50
# Solution ID=985.8307892499676 evaluated with score=15.50
# Solution ID=985.4112267302395 evaluated with score=22.25
# Solution ID=985.4112267302395 evaluated with score=22.25
# Solution ID=985.6971335340824 evaluated with score=12.75
# Solution ID=985.6971335340824 evaluated with score=12.75
# Solution ID=985.4699739770424 evaluated with score=30.50
# Solution ID=985.4699739770424 evaluated with score=30.50
# Solution ID=985.9419431554312 evaluated with score=12.75
# Solution ID=985.9419431554312 evaluated with score=12.75
# Iteration 986 ended. Best in batch = 30.50
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=497, cov=0.552, mean=20.96, best=45.25
#
# === Starting iteration 987 ===
# Emitter.ask() called for iteration 987
# Mutating solutions for iteration 987
# Solution ID=986.2104155435346 evaluated with score=7.75
# Solution ID=986.2138018896283 evaluated with score=9.75
# Solution ID=986.5306408060765 evaluated with score=12.25
# Solution ID=986.114763403024 evaluated with score=12.50
# Solution ID=986.7242162772959 evaluated with score=5.50
# Solution ID=986.392164160249 evaluated with score=21.75
# Solution ID=986.3218571663001 evaluated with score=29.00
# Solution ID=986.317495382079 evaluated with score=10.75
# Solution ID=986.8417199235413 evaluated with score=18.50
# Solution ID=986.7645591527491 evaluated with score=11.25
# Iteration 987 ended. Best in batch = 29.00
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=499, cov=0.554, mean=20.95, best=45.25
#
# === Starting iteration 988 ===
# Emitter.ask() called for iteration 988
# Crossover solutions for iteration 988
# Solution ID=987.7032921002618 evaluated with score=27.75
# Solution ID=987.7032921002618 evaluated with score=27.75
# Solution ID=987.8584353401186 evaluated with score=8.25
# Solution ID=987.8584353401186 evaluated with score=8.25
# Solution ID=987.7109685301335 evaluated with score=19.00
# Solution ID=987.7109685301335 evaluated with score=19.00
# Solution ID=987.8261836894376 evaluated with score=12.00
# Solution ID=987.8261836894376 evaluated with score=12.00
# Solution ID=987.126046351784 evaluated with score=11.25
# Solution ID=987.126046351784 evaluated with score=11.25
# Iteration 988 ended. Best in batch = 27.75
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=499, cov=0.554, mean=20.96, best=45.25
#
# === Starting iteration 989 ===
# Emitter.ask() called for iteration 989
# Crossover solutions for iteration 989
# Solution ID=988.5763388661966 evaluated with score=5.25
# Solution ID=988.5763388661966 evaluated with score=5.25
# Solution ID=988.1779917945794 evaluated with score=16.00
# Solution ID=988.1779917945794 evaluated with score=16.00
# Solution ID=988.9514718285088 evaluated with score=34.75
# Solution ID=988.9514718285088 evaluated with score=34.75
# Solution ID=988.8135707740615 evaluated with score=8.00
# Solution ID=988.8135707740615 evaluated with score=8.00
# Solution ID=988.1867097072388 evaluated with score=31.00
# Solution ID=988.1867097072388 evaluated with score=31.00
# Iteration 989 ended. Best in batch = 34.75
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=501, cov=0.557, mean=21.01, best=45.25
#
# === Starting iteration 990 ===
# Emitter.ask() called for iteration 990
# Crossover solutions for iteration 990
# Solution ID=989.7427810281465 evaluated with score=12.25
# Solution ID=989.7427810281465 evaluated with score=12.25
# Solution ID=989.6243463106879 evaluated with score=15.75
# Solution ID=989.6243463106879 evaluated with score=15.75
# Solution ID=989.7189913020325 evaluated with score=11.50
# Solution ID=989.7189913020325 evaluated with score=11.50
# Solution ID=989.9513665688028 evaluated with score=7.00
# Solution ID=989.9513665688028 evaluated with score=7.00
# Solution ID=989.0474051768484 evaluated with score=12.75
# Solution ID=989.0474051768484 evaluated with score=12.75
# Iteration 990 ended. Best in batch = 15.75
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=481, cov=0.534, mean=21.13, best=45.25
#
# === Starting iteration 991 ===
# Emitter.ask() called for iteration 991
# Crossover solutions for iteration 991
# Solution ID=990.0657244608992 evaluated with score=12.75
# Solution ID=990.0657244608992 evaluated with score=12.75
# Solution ID=990.9878644359917 evaluated with score=7.25
# Solution ID=990.9878644359917 evaluated with score=7.25
# Solution ID=990.0177434104087 evaluated with score=22.25
# Solution ID=990.0177434104087 evaluated with score=22.25
# Solution ID=990.427630545866 evaluated with score=9.00
# Solution ID=990.427630545866 evaluated with score=9.00
# Solution ID=990.0053025623743 evaluated with score=28.50
# Solution ID=990.0053025623743 evaluated with score=28.50
# Iteration 991 ended. Best in batch = 28.50
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=482, cov=0.536, mean=21.14, best=45.25
#
# === Starting iteration 992 ===
# Emitter.ask() called for iteration 992
# Mutating solutions for iteration 992
# Warning: clamping bad score for ID=991.0648780525161 (500 Server Error: Internal Server Error for url: http://localhost:4242/evaluate)
# Solution ID=991.4457164323665 evaluated with score=28.00
# Solution ID=991.0648780525161 evaluated with score=18.00
# Solution ID=991.1779338159893 evaluated with score=24.50
# Solution ID=991.7767941755872 evaluated with score=30.75
# Solution ID=991.7580722246967 evaluated with score=18.75
# Solution ID=991.7189913020325 evaluated with score=14.75
# Solution ID=991.6530664985637 evaluated with score=12.50
# Solution ID=991.7771795337787 evaluated with score=12.50
# Solution ID=991.3450023568724 evaluated with score=8.50
# Iteration 992 ended. Best in batch = 30.75
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=482, cov=0.536, mean=21.24, best=45.25
#
# === Starting iteration 993 ===
# Emitter.ask() called for iteration 993
# Mutating solutions for iteration 993
# Warning: clamping bad score for ID=992.6531218062194 (500 Server Error: Internal Server Error for url: http://localhost:4242/evaluate)
# Solution ID=992.0870165572553 evaluated with score=11.50
# Solution ID=992.6531218062194 evaluated with score=7.50
# Solution ID=992.9247391211738 evaluated with score=13.00
# Solution ID=992.4807397977472 evaluated with score=4.75
# Solution ID=992.7905892089545 evaluated with score=13.00
# Solution ID=992.7298545851697 evaluated with score=17.25
# Solution ID=992.4012412172975 evaluated with score=6.75
# Solution ID=992.2798837006605 evaluated with score=15.25
# Solution ID=992.7645591527491 evaluated with score=13.25
# Iteration 993 ended. Best in batch = 17.25
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=485, cov=0.539, mean=21.17, best=45.25
#
# === Starting iteration 994 ===
# Emitter.ask() called for iteration 994
# Mutating solutions for iteration 994
# Solution ID=993.4139307671533 evaluated with score=2.75
# Solution ID=993.4963776044709 evaluated with score=14.75
# Solution ID=993.7462001742083 evaluated with score=20.00
# Solution ID=993.7137990316705 evaluated with score=11.00
# Solution ID=993.8827201087092 evaluated with score=7.00
# Solution ID=993.3218571663001 evaluated with score=17.00
# Solution ID=993.5922324380417 evaluated with score=8.50
# Solution ID=993.7702600846235 evaluated with score=5.50
# Solution ID=993.5250212994791 evaluated with score=20.25
# Solution ID=993.5306408060765 evaluated with score=4.25
# Iteration 994 ended. Best in batch = 20.25
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=487, cov=0.541, mean=21.11, best=45.25
#
# === Starting iteration 995 ===
# Emitter.ask() called for iteration 995
# Crossover solutions for iteration 995
# Solution ID=994.5592905690927 evaluated with score=7.00
# Solution ID=994.5592905690927 evaluated with score=7.00
# Solution ID=994.8220123865178 evaluated with score=12.75
# Solution ID=994.8220123865178 evaluated with score=12.75
# Solution ID=994.2956199436811 evaluated with score=28.25
# Solution ID=994.2956199436811 evaluated with score=28.25
# Solution ID=994.7894010824099 evaluated with score=18.50
# Solution ID=994.7894010824099 evaluated with score=18.50
# Solution ID=994.3328677604586 evaluated with score=9.00
# Solution ID=994.3328677604586 evaluated with score=9.00
# Iteration 995 ended. Best in batch = 28.25
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=487, cov=0.541, mean=21.12, best=45.25
#
# === Starting iteration 996 ===
# Emitter.ask() called for iteration 996
# Crossover solutions for iteration 996
# Solution ID=995.7179445510798 evaluated with score=8.25
# Solution ID=995.7179445510798 evaluated with score=8.25
# Solution ID=995.6185980028104 evaluated with score=7.25
# Solution ID=995.6185980028104 evaluated with score=7.25
# Solution ID=995.1042025325493 evaluated with score=14.75
# Solution ID=995.1042025325493 evaluated with score=14.75
# Solution ID=995.7891401881022 evaluated with score=5.50
# Solution ID=995.7891401881022 evaluated with score=5.50
# Solution ID=995.9767970452416 evaluated with score=17.00
# Solution ID=995.9767970452416 evaluated with score=17.00
# Iteration 996 ended. Best in batch = 17.00
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=490, cov=0.544, mean=21.03, best=45.25
#
# === Starting iteration 997 ===
# Emitter.ask() called for iteration 997
# Crossover solutions for iteration 997
# Solution ID=996.4301675764143 evaluated with score=10.75
# Solution ID=996.4301675764143 evaluated with score=10.75
# Solution ID=996.8558049301188 evaluated with score=9.25
# Solution ID=996.8558049301188 evaluated with score=9.25
# Solution ID=996.376479109334 evaluated with score=22.50
# Solution ID=996.376479109334 evaluated with score=22.50
# Solution ID=996.0892834402101 evaluated with score=10.50
# Solution ID=996.0892834402101 evaluated with score=10.50
# Solution ID=996.2320553636431 evaluated with score=24.25
# Solution ID=996.2320553636431 evaluated with score=24.25
# Iteration 997 ended. Best in batch = 24.25
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=490, cov=0.544, mean=21.06, best=45.25
#
# === Starting iteration 998 ===
# Emitter.ask() called for iteration 998
# Mutating solutions for iteration 998
# Warning: clamping bad score for ID=997.4730640146709 (500 Server Error: Internal Server Error for url: http://localhost:4242/evaluate)
# Solution ID=997.3152829585116 evaluated with score=19.75
# Solution ID=997.12655499976 evaluated with score=12.25
# Solution ID=997.4730640146709 evaluated with score=9.00
# Solution ID=997.3218571663001 evaluated with score=28.25
# Solution ID=997.7461040959377 evaluated with score=11.25
# Solution ID=997.7771795337787 evaluated with score=18.25
# Solution ID=997.0383426839276 evaluated with score=20.25
# Solution ID=997.6216268743278 evaluated with score=14.25
# Solution ID=997.8179719571943 evaluated with score=7.75
# Iteration 998 ended. Best in batch = 28.25
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=492, cov=0.547, mean=21.06, best=45.25
#
# === Starting iteration 999 ===
# Emitter.ask() called for iteration 999
# Crossover solutions for iteration 999
# Solution ID=998.5255102087107 evaluated with score=16.50
# Solution ID=998.5255102087107 evaluated with score=16.50
# Solution ID=998.034271730832 evaluated with score=15.50
# Solution ID=998.034271730832 evaluated with score=15.50
# Solution ID=998.9547460461466 evaluated with score=18.75
# Solution ID=998.9547460461466 evaluated with score=18.75
# Solution ID=998.014908592221 evaluated with score=12.25
# Solution ID=998.014908592221 evaluated with score=12.25
# Solution ID=998.8728204108916 evaluated with score=7.50
# Solution ID=998.8728204108916 evaluated with score=7.50
# Iteration 999 ended. Best in batch = 18.75
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=492, cov=0.547, mean=21.07, best=45.25
#
# === Starting iteration 1000 ===
# Emitter.ask() called for iteration 1000
# Mutating solutions for iteration 1000
# Solution ID=999.0838826677902 evaluated with score=19.25
# Solution ID=999.0205860040569 evaluated with score=5.25
# Solution ID=999.7427810281465 evaluated with score=5.25
# Solution ID=999.114763403024 evaluated with score=19.50
# Solution ID=999.3387143021498 evaluated with score=16.50
# Solution ID=999.6530664985637 evaluated with score=8.50
# Solution ID=999.4730640146709 evaluated with score=18.50
# Solution ID=999.5200813393614 evaluated with score=10.00
# Solution ID=999.9127343966114 evaluated with score=9.25
# Solution ID=999.5820089652968 evaluated with score=6.25
# Iteration 1000 ended. Best in batch = 19.50
# Global best so far: 45.25 (ID=386.45000235249245)
# Archive size=483, cov=0.537, mean=20.99, best=45.25
# [Checkpoint] Saved data/checkpoints/checkpoint_1000.pkl

# %%
data      = archive.data()
objs      = data["objective"]
size      = len(archive)
coverage  = archive.stats.coverage

print(f"Final archive size={size}, Coverage={coverage:.3f}")
print(f"Archive size     : {size}")
print(f"Coverage         : {coverage:.3%}")
print(f"Best objective   : {objs.max():.3f}")
print(f"Mean objective   : {objs[objs != INVALID_SCORE].mean():.3f}\n")

k = 10                                        # how many to list
for i in range(min(k, size)):
    sol_vec = data["solution"][i]
    sol_id  = sol_vec[-1]
    umap_xy = data["measures"][i]
    print(f"{i+1:2d}. "
          f"ID={sol_id:.17f}   "
          f"UMAP=({umap_xy[0]:7.3f}, {umap_xy[1]:7.3f})")
# Out:
# Final archive size=483, Coverage=0.537
# Archive size     : 483
# Coverage         : 53.667%
# Best objective   : 45.250
# Mean objective   : 20.985
#
#  1. ID=285.47705091086203311   UMAP=( 18.027,   8.026)
#  2. ID=307.60541815414211442   UMAP=( 18.010,   6.939)
#  3. ID=227.56105069443458433   UMAP=( 16.938,   5.564)
#  4. ID=5.32233009707676885   UMAP=(  4.040,   0.415)
#  5. ID=279.53064080607640562   UMAP=( 17.503,   7.897)
#  6. ID=145.08388266779024889   UMAP=( 17.103,   4.150)
#  7. ID=271.60665523690357759   UMAP=( 15.977,   7.326)
#  8. ID=81.44571643236650971   UMAP=(  4.395,   7.615)
#  9. ID=819.07074382646533195   UMAP=(  4.401,   0.721)
# 10. ID=26.57022825827028711   UMAP=(  4.342,   3.476)

# %%
from utils import array_to_solution # Re-importing array_to_solution here just in case, though it's technically in the 
target_x = 10.0   # change this as needed
k = 4

measures = data["measures"]                    # (N, 2) array
dx       = np.abs(measures[:, 0] - target_x)   # distance to target on x-axis

nearest_idx = np.argsort(dx)[:k]               # indices of the k closest

for rank, idx in enumerate(nearest_idx, 1):
    sol_vec = data["solution"][idx]
    sol_id  = sol_vec[-1]
    umap_xy = measures[idx]
    score   = objs[idx]
    print(f"{rank:2d}. "
          f"ID={sol_id:.17f}   "
          f"dx={dx[idx]:7.3f}   "
          f"score={score:8.3f}   "
          f"UMAP=({umap_xy[0]:7.3f}, {umap_xy[1]:7.3f})")


# ----------------------------------------------------------
# Plotting the scatter + highlight
# ----------------------------------------------------------

all_x, all_y = measures[:, 0], measures[:, 1]

plt.figure(figsize=(8, 6))
sc = plt.scatter(all_x, all_y,
                 c=objs,                # colour scale = performance
                 s=12,                  # dot size
                 alpha=0.8,
                 cmap="viridis")

# highlight the nearest k in red with black edge
highlight = measures[nearest_idx]
plt.scatter(highlight[:, 0], highlight[:, 1],
            facecolors='none',
            edgecolors='red',
            s=80,
            linewidths=1.5,
            label=f"{len(nearest_idx)} closest to UMAP-x={target_x}")

plt.colorbar(sc, label="Objective value")
plt.title("Archive in UMAP space\n(highlighted = closest to target x)")
plt.xlabel("UMAP-1")
plt.ylabel("UMAP-2")
plt.legend(loc="lower right")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 from utilities import array_to_solution # Re-importing array_to_solution here just in case, though it's technically in the imports already.
#       2 from utilities import _STATS # Import global stats from utilities for inspection
#       4 target_x = 10.0   # change this as needed
#
# ModuleNotFoundError: No module named 'utilities'

# %%
m = 15                                   # how many random elites to inspect
rng = np.random.default_rng(42)          # reproducible
rand_idx = rng.choice(len(archive), size=m, replace=False)

samples = []                             # keep the decoded solutions here

for j, idx in enumerate(rand_idx, 1):
    sol_vec = data["solution"][idx]
    sol_id  = sol_vec[-1]
    umap_xy = data["measures"][idx]
    score   = objs[idx]
    print(f"{j:2d}. ID={sol_id:.17f}   "
          f"score={score:8.3f}   "
          f"UMAP=({umap_xy[0]:7.3f}, {umap_xy[1]:7.3f})")
    
    # store full dict in `samples` for later, if desired
    samples.append(array_to_solution(sol_vec))


# --------------------------------------------------------------
# Plotting the 2D Histogram
# --------------------------------------------------------------

# Filter INVALID_SCOREs before computing mean/std
valid_objs = objs[objs != INVALID_SCORE]
if len(valid_objs) > 0:
    obj_mean = valid_objs.mean()
    obj_std  = valid_objs.std()
else:
    obj_mean = 0.0
    obj_std = 0.0

# Set outlier bounds based on the mean of valid objectives
lo, hi   = obj_mean - 3*obj_std, obj_mean + 3*obj_std

# Create mask by filtering out INVALID_SCOREs and outliers
valid_mask = objs != INVALID_SCORE
outlier_mask = (objs[valid_mask] >= lo) & (objs[valid_mask] <= hi)
final_mask = np.zeros_like(objs, dtype=bool)
final_mask[valid_mask] = outlier_mask

x_f, y_f = all_x[final_mask], all_y[final_mask]
w_f      = objs[final_mask]                       # colour = objective value

plt.figure(figsize=(8, 6))
# Only plot if there are valid and non-outlier points remaining
if len(x_f) > 0:
    hb = plt.hist2d(x_f, y_f,
                    bins=50,
                    weights=w_f,
                    cmap="plasma",
                    # Centering colour bar around the mean 
                    vmin=obj_mean - obj_std,
                    vmax=obj_mean + obj_std)

    plt.colorbar(hb[3], label="Mean objective in bin")
else:
    plt.text(0.5, 0.5, "No valid data to plot after outlier filtering.", 
             ha='center', va='center', transform=plt.gca().transAxes)
    
plt.title("Performance landscape (outliers clipped, scale ~ mean ±1 σ)")
plt.xlabel("UMAP-1")
plt.ylabel("UMAP-2")
plt.tight_layout()
plt.show()
